# %%
list = [1]

# %%
print(list)
# Out:
# [1]

# %%
fruits = [ "Apple", "Mangoes", "Banana" ]
for index in enumerate(fruits):
    print(index)
# Out:
# (0, 'Apple')
# (1, 'Mangoes')
# (2, 'Banana')

# %%
#task 01

# %%
name = str(input("enter your name"))
age = int(input("enter your age"))
print(name)
print(age)
print("Hello {name} you are {age} years old")
# Out:
# enter your name safwan
# enter your age 23
# safwan
# 23
# Hello {name} you are {age} years old

# %%
#task 2

# %%
a =int(input("enter first no a"))
b = int(input("enter second no b"))
sum = a + b
print ("the sum is : ",sum)
# Out:
# enter first no a 10
# enter second no b 20
# the sum is :  30

# %%
#task14

# %%
list = ["netsol", "is", "netsol"]
for i in range(1):
    print(list[0])
    print(list[1])
    print(list[2])
# Out:
# netsol
# is
# netsol

# %%
list = ["netsol"]
for i in range(1):
    print(list[0])
# Out:
# netsol

# %%
list = ["netsolpark"]
for i in range(0,1):
    print(list[0])
    if (i == n AND i == s):
        print("netsolpark")
    elif
# Out:
#   Cell In[72], line 4
#     if (i == n AND i == s):
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
def check_number(number):
    if (number ==  odd_number):
        odd_number = [1,3,5,7,9]
        print("number is odd")
        print(number)
def myfunction():

    first_name = str(input("enter your first name"))                     
    last_name  = str(input("enter your second name"))
    print("you enter first_name",first_name)
    print("you enter second_name",second_name)
    
    return myfunction
